# %% [markdown]
# <a href="https://colab.research.google.com/github/harikadevireddy9/dl/blob/main/Bitempered_Logistic_Loss.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/surmenok/keras_lr_finder.git keras_lr_finder_repo
# !mv keras_lr_finder_repo/keras_lr_finder keras_lr_finder
# !git clone https://github.com/google/bi-tempered-loss.git
# !mv bi-tempered-loss/tensorflow/loss.py loss.py
# !rm -r keras_lr_finder_repo bi-tempered-loss
# Out:
# Cloning into 'keras_lr_finder_repo'...
# remote: Enumerating objects: 68, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 68 (delta 1), reused 2 (delta 0), pack-reused 62
# Receiving objects: 100% (68/68), 55.78 KiB | 1.30 MiB/s, done.
# Resolving deltas: 100% (23/23), done.
# Cloning into 'bi-tempered-loss'...
# remote: Enumerating objects: 152, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 152 (delta 15), reused 11 (delta 5), pack-reused 122
# Receiving objects: 100% (152/152), 65.60 KiB | 1.26 MiB/s, done.
# Resolving deltas: 100% (85/85), done.

# %%
# !git clone https://github.com/DumalaAnveshini/bitempered.git
from bitempered.utils import generate_points, mix_cifar, mix_points, points_to_data, get_best_lr
# Out:
# Cloning into 'bitempered'...
# remote: Enumerating objects: 8, done.
# remote: Counting objects: 100% (8/8), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 8 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (8/8), 740.39 KiB | 5.52 MiB/s, done.

# %%
from bitempered.plotting import plot_cifar, plot_points, plot_synthetic_results, plot_cifar_results, plot_lr_finding_results

# %%
from loss import _internal_bi_tempered_logistic_loss as bi_tempered_logistic_loss
from keras_lr_finder.lr_finder import LRFinder

# %%
import ssl

import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.applications import resnet50
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.layers import Dense, Flatten, InputLayer, UpSampling2D
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# # Bi-tempered logistic loss analysis
# ### Performance
# Standard logistic loss:

# %%
cce = CategoricalCrossentropy(from_logits=False)
# %timeit cce(np.random.rand(1000, 10).astype(np.float32), np.random.rand(1000, 10).astype(np.float32))
# Out:
# 1.25 ms ± 95.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit bi_tempered_logistic_loss(np.random.rand(1000, 10).astype(np.float32), np.random.rand(1000, 10).astype(np.float32), 0.5, 2.)
# Out:
# 5.59 ms ± 115 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# Wrapper

# %%
class BiTemperedWrapper:

    def __init__(self, t1=1., t2=1.):
        self.t1 = t1
        self.t2 = t2
        self.cce = CategoricalCrossentropy(from_logits=True)

    def __call__(self, labels, activations):
        if self.t1 == 1. and self.t2 == 1.:
            return self.cce(labels, activations)
        return bi_tempered_logistic_loss(activations, labels, self.t1,  self.t2)

# %% [markdown]
# Synthetic Dataset

# %%
blue_train = generate_points(1200, 0, 5)
red_train = generate_points(1200, 6, 8)
blue_train_margin_noise, red_train_margin_noise = np.copy(blue_train), np.copy(red_train)
blue_train_global_noise, red_train_global_noise = np.copy(blue_train), np.copy(red_train)

mix_points(blue_train_margin_noise, red_train_margin_noise, 4, 7, 0.2)
mix_points(blue_train_global_noise, red_train_global_noise, 0, 8, 0.2)

plt.figure(figsize=(17, 5))
plt.subplot(1, 3, 1)
plt.title("Training data\nwithout noise")
plot_points([blue_train, red_train], 8)

plt.subplot(1, 3, 2)
plt.title("Training data\n20% margin noise")
plot_points([blue_train_margin_noise, red_train_margin_noise], 8)

plt.subplot(1, 3, 3)
plt.title("Training data\n20% global noise")
plot_points([blue_train_global_noise, red_train_global_noise], 8)
plt.show()

plt.figure(figsize=(6, 5))
blue_valid = generate_points(300, 0, 5)
red_valid = generate_points(300, 6, 8)
plt.title("Validation data")
plot_points([blue_valid, red_valid], 8)
plt.show()

# %%
X_train, y_train = points_to_data(blue_train, red_train)
X_train_margin, y_train_margin = points_to_data(blue_train_margin_noise, red_train_margin_noise)
X_train_global, y_train_global = points_to_data(blue_train_global_noise, red_train_global_noise)

X_valid, y_valid = points_to_data(blue_valid, red_valid)

# %%
def synthetic_model():
    return Sequential([
        InputLayer(input_shape=X_train[0].shape),
        Dense(32, activation='relu'),
        Dense(32, activation='relu'),
        Dense(2)
    ])

# %%
datasets = {'noise free': (X_train, y_train),
            'margin': (X_train_margin, y_train_margin),
            'global': (X_train_global, y_train_global)}
temp_vals = [(1., 1.), (0.2, 4.0)]
results = {}
for dataset_name, (X_data, y_data) in datasets.items():
    results[dataset_name] = {}
    for temps in temp_vals:
        results[dataset_name][temps] = {}
        model = synthetic_model()
        model.compile(loss=BiTemperedWrapper(*temps), optimizer=Adam(), metrics=['accuracy'])
        history = model.fit(X_data, y_data, validation_data=(X_valid, y_valid), epochs=20)
        results[dataset_name][temps]['model'] = model
        results[dataset_name][temps]['history'] = history.history
# Out:
# Epoch 1/20
# 75/75 [==============================] - 1s 4ms/step - loss: 0.6152 - accuracy: 0.5633 - val_loss: 0.5266 - val_accuracy: 0.7017
# Epoch 2/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.4749 - accuracy: 0.7563 - val_loss: 0.4000 - val_accuracy: 0.8617
# Epoch 3/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.3390 - accuracy: 0.8788 - val_loss: 0.2469 - val_accuracy: 0.9400
# Epoch 4/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2059 - accuracy: 0.9492 - val_loss: 0.1493 - val_accuracy: 0.9900
# Epoch 5/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1309 - accuracy: 0.9783 - val_loss: 0.0940 - val_accuracy: 0.9883
# Epoch 6/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0892 - accuracy: 0.9896 - val_loss: 0.0642 - val_accuracy: 1.0000
# Epoch 7/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0638 - accuracy: 0.9958 - val_loss: 0.0482 - val_accuracy: 1.0000
# Epoch 8/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0482 - accuracy: 0.9987 - val_loss: 0.0347 - val_accuracy: 1.0000
# Epoch 9/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0350 - accuracy: 1.0000 - val_loss: 0.0281 - val_accuracy: 1.0000
# Epoch 10/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0256 - accuracy: 1.0000 - val_loss: 0.0191 - val_accuracy: 1.0000
# Epoch 11/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0209 - accuracy: 1.0000 - val_loss: 0.0162 - val_accuracy: 1.0000
# Epoch 12/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0174 - accuracy: 1.0000 - val_loss: 0.0129 - val_accuracy: 1.0000
# Epoch 13/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.0095 - val_accuracy: 1.0000
# Epoch 14/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.0091 - val_accuracy: 1.0000
# Epoch 15/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 16/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 17/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 18/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 19/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.0051 - val_accuracy: 1.0000
# Epoch 20/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 1/20
# 75/75 [==============================] - 3s 6ms/step - loss: 0.2644 - accuracy: 0.5337 - val_loss: 0.2538 - val_accuracy: 0.5750
# Epoch 2/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2494 - accuracy: 0.6204 - val_loss: 0.2397 - val_accuracy: 0.6700
# Epoch 3/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.2312 - accuracy: 0.7329 - val_loss: 0.2153 - val_accuracy: 0.7917
# Epoch 4/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2021 - accuracy: 0.8433 - val_loss: 0.1804 - val_accuracy: 0.9000
# Epoch 5/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1670 - accuracy: 0.9250 - val_loss: 0.1466 - val_accuracy: 0.9700
# Epoch 6/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1374 - accuracy: 0.9708 - val_loss: 0.1208 - val_accuracy: 0.9783
# Epoch 7/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1157 - accuracy: 0.9837 - val_loss: 0.1045 - val_accuracy: 0.9917
# Epoch 8/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0995 - accuracy: 0.9937 - val_loss: 0.0907 - val_accuracy: 0.9917
# Epoch 9/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0885 - accuracy: 0.9946 - val_loss: 0.0811 - val_accuracy: 0.9983
# Epoch 10/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0794 - accuracy: 0.9971 - val_loss: 0.0736 - val_accuracy: 0.9983
# Epoch 11/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0723 - accuracy: 0.9992 - val_loss: 0.0679 - val_accuracy: 0.9983
# Epoch 12/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0668 - accuracy: 0.9996 - val_loss: 0.0630 - val_accuracy: 1.0000
# Epoch 13/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0623 - accuracy: 1.0000 - val_loss: 0.0585 - val_accuracy: 1.0000
# Epoch 14/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.0584 - accuracy: 0.9996 - val_loss: 0.0553 - val_accuracy: 1.0000
# Epoch 15/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0550 - accuracy: 1.0000 - val_loss: 0.0524 - val_accuracy: 1.0000
# Epoch 16/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0520 - accuracy: 1.0000 - val_loss: 0.0497 - val_accuracy: 1.0000
# Epoch 17/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0494 - accuracy: 1.0000 - val_loss: 0.0474 - val_accuracy: 1.0000
# Epoch 18/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0470 - accuracy: 1.0000 - val_loss: 0.0452 - val_accuracy: 1.0000
# Epoch 19/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0449 - accuracy: 1.0000 - val_loss: 0.0429 - val_accuracy: 1.0000
# Epoch 20/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0429 - accuracy: 1.0000 - val_loss: 0.0415 - val_accuracy: 1.0000
# Epoch 1/20
# 75/75 [==============================] - 1s 3ms/step - loss: 0.5871 - accuracy: 0.6454 - val_loss: 0.4866 - val_accuracy: 0.7517
# Epoch 2/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.4427 - accuracy: 0.8087 - val_loss: 0.3440 - val_accuracy: 0.9300
# Epoch 3/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.3051 - accuracy: 0.9067 - val_loss: 0.1973 - val_accuracy: 0.9700
# Epoch 4/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2147 - accuracy: 0.9396 - val_loss: 0.1384 - val_accuracy: 0.9833
# Epoch 5/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1761 - accuracy: 0.9492 - val_loss: 0.1038 - val_accuracy: 0.9867
# Epoch 6/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1583 - accuracy: 0.9533 - val_loss: 0.0966 - val_accuracy: 0.9967
# Epoch 7/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1505 - accuracy: 0.9550 - val_loss: 0.0756 - val_accuracy: 0.9933
# Epoch 8/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1392 - accuracy: 0.9554 - val_loss: 0.0578 - val_accuracy: 0.9900
# Epoch 9/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1401 - accuracy: 0.9550 - val_loss: 0.0573 - val_accuracy: 0.9867
# Epoch 10/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1371 - accuracy: 0.9558 - val_loss: 0.0722 - val_accuracy: 0.9917
# Epoch 11/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1406 - accuracy: 0.9546 - val_loss: 0.0487 - val_accuracy: 0.9967
# Epoch 12/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1365 - accuracy: 0.9558 - val_loss: 0.0503 - val_accuracy: 0.9917
# Epoch 13/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1368 - accuracy: 0.9563 - val_loss: 0.0528 - val_accuracy: 0.9833
# Epoch 14/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1332 - accuracy: 0.9588 - val_loss: 0.0546 - val_accuracy: 0.9917
# Epoch 15/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1339 - accuracy: 0.9550 - val_loss: 0.0494 - val_accuracy: 0.9983
# Epoch 16/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1327 - accuracy: 0.9554 - val_loss: 0.0532 - val_accuracy: 0.9983
# Epoch 17/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1367 - accuracy: 0.9550 - val_loss: 0.0389 - val_accuracy: 1.0000
# Epoch 18/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1319 - accuracy: 0.9571 - val_loss: 0.0448 - val_accuracy: 0.9933
# Epoch 19/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1305 - accuracy: 0.9533 - val_loss: 0.0415 - val_accuracy: 1.0000
# Epoch 20/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1345 - accuracy: 0.9567 - val_loss: 0.0398 - val_accuracy: 0.9950
# Epoch 1/20
# 75/75 [==============================] - 4s 19ms/step - loss: 0.2672 - accuracy: 0.5312 - val_loss: 0.2544 - val_accuracy: 0.5767
# Epoch 2/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2497 - accuracy: 0.6404 - val_loss: 0.2340 - val_accuracy: 0.7233
# Epoch 3/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2223 - accuracy: 0.7796 - val_loss: 0.1958 - val_accuracy: 0.8783
# Epoch 4/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1830 - accuracy: 0.8938 - val_loss: 0.1538 - val_accuracy: 0.9567
# Epoch 5/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1508 - accuracy: 0.9317 - val_loss: 0.1259 - val_accuracy: 0.9783
# Epoch 6/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1296 - accuracy: 0.9429 - val_loss: 0.1054 - val_accuracy: 0.9817
# Epoch 7/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1153 - accuracy: 0.9496 - val_loss: 0.0911 - val_accuracy: 0.9950
# Epoch 8/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1048 - accuracy: 0.9513 - val_loss: 0.0814 - val_accuracy: 0.9950
# Epoch 9/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0978 - accuracy: 0.9546 - val_loss: 0.0741 - val_accuracy: 0.9933
# Epoch 10/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0924 - accuracy: 0.9567 - val_loss: 0.0680 - val_accuracy: 0.9950
# Epoch 11/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0882 - accuracy: 0.9542 - val_loss: 0.0639 - val_accuracy: 0.9983
# Epoch 12/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0850 - accuracy: 0.9558 - val_loss: 0.0597 - val_accuracy: 0.9983
# Epoch 13/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0819 - accuracy: 0.9571 - val_loss: 0.0565 - val_accuracy: 0.9967
# Epoch 14/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0793 - accuracy: 0.9579 - val_loss: 0.0549 - val_accuracy: 0.9950
# Epoch 15/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0781 - accuracy: 0.9546 - val_loss: 0.0517 - val_accuracy: 1.0000
# Epoch 16/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0761 - accuracy: 0.9550 - val_loss: 0.0492 - val_accuracy: 1.0000
# Epoch 17/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0740 - accuracy: 0.9583 - val_loss: 0.0492 - val_accuracy: 0.9933
# Epoch 18/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0726 - accuracy: 0.9558 - val_loss: 0.0455 - val_accuracy: 0.9983
# Epoch 19/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0709 - accuracy: 0.9596 - val_loss: 0.0462 - val_accuracy: 0.9933
# Epoch 20/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.0708 - accuracy: 0.9563 - val_loss: 0.0424 - val_accuracy: 1.0000
# Epoch 1/20
# 75/75 [==============================] - 1s 3ms/step - loss: 0.6563 - accuracy: 0.5833 - val_loss: 0.5445 - val_accuracy: 0.7383
# Epoch 2/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.6116 - accuracy: 0.6837 - val_loss: 0.4738 - val_accuracy: 0.8550
# Epoch 3/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.5816 - accuracy: 0.7325 - val_loss: 0.4155 - val_accuracy: 0.9550
# Epoch 4/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.5615 - accuracy: 0.7621 - val_loss: 0.3905 - val_accuracy: 0.9933
# Epoch 5/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.5504 - accuracy: 0.7746 - val_loss: 0.3436 - val_accuracy: 0.9783
# Epoch 6/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.5458 - accuracy: 0.7796 - val_loss: 0.3368 - val_accuracy: 0.9867
# Epoch 7/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.5427 - accuracy: 0.7854 - val_loss: 0.3463 - val_accuracy: 0.9633
# Epoch 8/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.5399 - accuracy: 0.7912 - val_loss: 0.2929 - val_accuracy: 0.9767
# Epoch 9/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.5367 - accuracy: 0.7867 - val_loss: 0.3099 - val_accuracy: 0.9950
# Epoch 10/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.5386 - accuracy: 0.7896 - val_loss: 0.3303 - val_accuracy: 0.9633
# Epoch 11/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.5370 - accuracy: 0.7937 - val_loss: 0.2888 - val_accuracy: 0.9900
# Epoch 12/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.5370 - accuracy: 0.7867 - val_loss: 0.2942 - val_accuracy: 1.0000
# Epoch 13/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.5316 - accuracy: 0.7946 - val_loss: 0.2820 - val_accuracy: 0.9933
# Epoch 14/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.5302 - accuracy: 0.7912 - val_loss: 0.2755 - val_accuracy: 0.9917
# Epoch 15/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.5313 - accuracy: 0.7929 - val_loss: 0.2594 - val_accuracy: 0.9833
# Epoch 16/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.5281 - accuracy: 0.7879 - val_loss: 0.2886 - val_accuracy: 0.9983
# Epoch 17/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.5281 - accuracy: 0.7962 - val_loss: 0.2572 - val_accuracy: 0.9883
# Epoch 18/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.5269 - accuracy: 0.7962 - val_loss: 0.2755 - val_accuracy: 0.9950
# Epoch 19/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.5252 - accuracy: 0.7958 - val_loss: 0.2756 - val_accuracy: 0.9917
# Epoch 20/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.5260 - accuracy: 0.7929 - val_loss: 0.3152 - val_accuracy: 0.9767
# Epoch 1/20
# 75/75 [==============================] - 3s 9ms/step - loss: 0.2845 - accuracy: 0.5117 - val_loss: 0.2639 - val_accuracy: 0.5617
# Epoch 2/20
# 75/75 [==============================] - 0s 4ms/step - loss: 0.2779 - accuracy: 0.5633 - val_loss: 0.2515 - val_accuracy: 0.6683
# Epoch 3/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.2683 - accuracy: 0.6354 - val_loss: 0.2281 - val_accuracy: 0.8083
# Epoch 4/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2540 - accuracy: 0.7108 - val_loss: 0.1986 - val_accuracy: 0.9067
# Epoch 5/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2403 - accuracy: 0.7571 - val_loss: 0.1711 - val_accuracy: 0.9500
# Epoch 6/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2290 - accuracy: 0.7771 - val_loss: 0.1550 - val_accuracy: 0.9817
# Epoch 7/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2208 - accuracy: 0.7887 - val_loss: 0.1374 - val_accuracy: 0.9717
# Epoch 8/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2155 - accuracy: 0.7917 - val_loss: 0.1256 - val_accuracy: 0.9883
# Epoch 9/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2116 - accuracy: 0.7950 - val_loss: 0.1204 - val_accuracy: 1.0000
# Epoch 10/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2088 - accuracy: 0.7967 - val_loss: 0.1109 - val_accuracy: 0.9867
# Epoch 11/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2058 - accuracy: 0.7975 - val_loss: 0.1035 - val_accuracy: 1.0000
# Epoch 12/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2042 - accuracy: 0.7971 - val_loss: 0.0979 - val_accuracy: 0.9983
# Epoch 13/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2031 - accuracy: 0.7975 - val_loss: 0.0977 - val_accuracy: 0.9950
# Epoch 14/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2014 - accuracy: 0.7975 - val_loss: 0.0916 - val_accuracy: 1.0000
# Epoch 15/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.2003 - accuracy: 0.7987 - val_loss: 0.0928 - val_accuracy: 0.9983
# Epoch 16/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1995 - accuracy: 0.7996 - val_loss: 0.0841 - val_accuracy: 0.9983
# Epoch 17/20
# 75/75 [==============================] - 0s 2ms/step - loss: 0.1988 - accuracy: 0.7987 - val_loss: 0.0849 - val_accuracy: 1.0000
# Epoch 18/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1982 - accuracy: 0.7979 - val_loss: 0.0831 - val_accuracy: 1.0000
# Epoch 19/20
# 75/75 [==============================] - 0s 3ms/step - loss: 0.1976 - accuracy: 0.7992 - val_loss: 0.0779 - val_accuracy: 1.0000
# Epoch 20/20
# 75/75 [==============================] - 0s 4ms/step - loss: 0.1970 - accuracy: 0.7975 - val_loss: 0.0764 - val_accuracy: 1.0000

# %%
plot_synthetic_results(*datasets['noise free'], results['noise free'], 'Noise free dataset')
plot_synthetic_results(*datasets['margin'], results['margin'], '20% margin noise')
plot_synthetic_results(*datasets['global'], results['global'], '20% global noise')
# Out:
# 82/82 [==============================] - 0s 921us/step
# 82/82 [==============================] - 0s 921us/step
# 82/82 [==============================] - 0s 995us/step
# 82/82 [==============================] - 0s 901us/step
# 82/82 [==============================] - 0s 1ms/step
# 82/82 [==============================] - 0s 911us/step

# %% [markdown]
# Cifar

# %%
ssl._create_default_https_context = ssl._create_unverified_context
(X_train, y_train), (X_valid, y_valid) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 2s 0us/step

# %%
plot_cifar(X_train, y_train)

# %%
y_train_small_noise, small_noise_idx = mix_cifar(y_train, 0.1)
y_train_large_noise, large_noise_idx = mix_cifar(y_train, 0.2)

# %%
plot_cifar(X_train[small_noise_idx], y_train_small_noise[small_noise_idx])

# %%
X_train = resnet50.preprocess_input(X_train)
X_valid = resnet50.preprocess_input(X_valid)

y_train = to_categorical(y_train)
y_train_small_noise = to_categorical(y_train_small_noise)
y_train_large_noise = to_categorical(y_train_large_noise)
y_valid = to_categorical(y_valid)

# %%
def cifar_model():
    return Sequential([
        UpSampling2D((7, 7), input_shape=(32, 32, 3)),
        ResNet50(
            include_top=False,
            weights="imagenet",
            classes=10,
            pooling='avg'
        ),
        Flatten(),
        Dense(1024),
        Dense(512),
        Dense(10)
    ])

# %%
model = cifar_model()
model.save_weights('model.h5')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 0s 0us/step

# %%
datasets = {'noise free': (X_train, y_train),
            'small': (X_train, y_train_small_noise),
            'large': (X_train, y_train_large_noise)}
temp_vals = [(1.0, 1.0), (0.8, 1.2), (0.5, 2.0), (0.2, 4.0)]

# %%
best_lr = {}
finders = {}
for temps in temp_vals:
    model.load_weights('model.h5')
    model.compile(loss=BiTemperedWrapper(*temps), optimizer=SGD(momentum=0.8), metrics=['accuracy'])

    lr_finder = LRFinder(model)
    lr_finder.find(X_train, y_train, start_lr=1e-10, end_lr=100, batch_size=64)
    lr, loss = get_best_lr(lr_finder)
    best_lr[temps] = lr
    finders[temps] = lr_finder
# Out:
#   2/782 [..............................] - ETA: 7:09:08 - loss: 2.9698 - accuracy: 0.1172

# %%
plot_lr_finding_results(finders, get_best_lr)

# %%
results = {}
for dataset_name, (X_data, y_data) in datasets.items():
    results[dataset_name] = {}
    for temps in temp_vals:
        model.load_weights('model.h5')
        results[dataset_name][temps] = {}
        model.compile(loss=BiTemperedWrapper(*temps), optimizer=SGD(learning_rate=best_lr[temps], momentum=0.8), metrics=['accuracy'])
        history = model.fit(X_data, y_data, validation_data=(X_valid, y_valid), batch_size=64, epochs=40, steps_per_epoch=100)

        results[dataset_name][temps]['history'] = history.history
        np.save(f'{dataset_name}_{temps}', history.history)
        model.save_weights(f'{dataset_name}_{temps}.h5')

# %%
plot_cifar_results(results['noise free'], 'Noise free dataset', max_annotations=[[0.88,0.9],[0.6,0.9],[0.75,0.75],[0.75,0.5]])
plot_cifar_results(results['small'], '10% noise', max_annotations=[[0.52,0.9],[0.1,0.9]])
plot_cifar_results(results['large'], '20% noise', max_annotations=[[0.57,0.9],[0.12,0.9]])
